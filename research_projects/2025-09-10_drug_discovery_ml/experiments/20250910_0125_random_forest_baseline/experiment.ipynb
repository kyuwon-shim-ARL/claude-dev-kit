# %% [markdown]
# # Experiment: random_forest_baseline
#
# **Started**: 2025-09-10T01:25:02.086299
# **Description**: Random Forest with Morgan fingerprints

# %%
# Experiment setup
import sys
sys.path.append('../../tools')

# Import project tools
# from your_module import your_function
