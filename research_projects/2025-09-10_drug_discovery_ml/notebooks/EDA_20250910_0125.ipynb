# %% [markdown]
# # Exploratory Data Analysis
#
# **Date**: 2025-09-10T01:25:38.864305
# **Description**: Exploring ChEMBL database for compound activity data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
# df = pd.read_csv('data/your_data.csv')
