# %% [markdown]
# # Experiment: 시퀀싱
#
# **Started**: 2025-09-10T01:35:54.026630
# **Description**: NGS 시퀀싱 진행

# %%
# Experiment setup
import sys
sys.path.append('../../tools')

# Import project tools
# from your_module import your_function
