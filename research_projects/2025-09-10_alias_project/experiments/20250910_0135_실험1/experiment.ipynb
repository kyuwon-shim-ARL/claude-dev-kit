# %% [markdown]
# # Experiment: 실험1
#
# **Started**: 2025-09-10T01:35:53.458527
# **Description**: 테스트 실험

# %%
# Experiment setup
import sys
sys.path.append('../../tools')

# Import project tools
# from your_module import your_function
