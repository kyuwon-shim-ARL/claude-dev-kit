# %% [markdown]
# # Experiment: rgcca_v2_sparse
#
# **Started**: 2025-09-10T01:54:28.188238
# **Description**: Sparse RGCCA with L1

# %%
# Experiment setup
import sys
sys.path.append('../../tools')

# Import project tools
# from your_module import your_function
