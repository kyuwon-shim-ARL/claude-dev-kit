# %% [markdown]
# # Experiment: baseline_rdkit
#
# **Started**: 2025-09-10T01:54:28.187297
# **Description**: RDKit descriptors only baseline

# %%
# Experiment setup
import sys
sys.path.append('../../tools')

# Import project tools
# from your_module import your_function
