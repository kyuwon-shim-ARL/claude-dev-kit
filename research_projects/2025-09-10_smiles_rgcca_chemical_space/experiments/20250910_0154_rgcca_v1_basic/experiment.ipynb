# %% [markdown]
# # Experiment: rgcca_v1_basic
#
# **Started**: 2025-09-10T01:54:28.187778
# **Description**: Basic RGCCA 차원 축소

# %%
# Experiment setup
import sys
sys.path.append('../../tools')

# Import project tools
# from your_module import your_function
