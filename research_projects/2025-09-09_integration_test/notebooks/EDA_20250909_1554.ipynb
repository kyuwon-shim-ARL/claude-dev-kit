# %% [markdown]
# # Exploratory Data Analysis
#
# **Date**: 2025-09-09T15:54:08.895748
# **Description**: Initial data exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
# df = pd.read_csv('data/your_data.csv')
